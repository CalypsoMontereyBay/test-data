# %% [markdown]
# # Fussing about

# %%
# imports
from remote_sensing import io as rs_io

# %% [markdown]
# # Load JSON

# %%
fp_110m = rs_io.loadjson('HS_flightplan1_110m_sim_worked.mission')

# %% [markdown]
# # Exploring

# %%
len(fp_110m['mission']['items'])
# Out:
# 63

# %%
tmp = fp_110m['mission']['items'][55].copy()
params = [0.0, 0.0, 0.0, 0.0, 36.9022912, -121.8657344, 110.0]

# %%
fp_110m['mission']['items'][55]['params'] = params
fp_110m['mission']['items'][55]
# Out:
# {'autoContinue': False,
#  'command': 82,
#  'doJumpId': 0,
#  'frame': 3,
#  'params': [0.0, 0.0, 0.0, 0.0, 36.9022912, -121.8657344, 110.0],
#  'type': None,
#  'TransectStyleComplexItem': None,
#  'angle': None,
#  'complexItemType': None,
#  'entryLocation': None,
#  'flyAlternateTransects': None,
#  'polygon': None,
#  'splitConcavePolygons': None,
#  'version': None}

# %% [markdown]
# # Write

# %%
rs_io.savejson('test_for_tim.mission', fp_110m)
